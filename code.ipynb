# %%
#importing needed libraries 
import matplotlib.pyplot as plt 
import pandas as pd 
from pathlib import Path
# %matplotlib inline

# %%
#Taking in the path to the files
file_accra_vec_tm = Path('Accra_vectorcapacity_Tm.csv')
file_accra_vec_tn = Path('Accra_vectorcapacity_Tn.csv')
file_accra_vec_tx = Path('Accra_vectorcapacity_Tx.csv')
file_kum_vec_tm   = Path('Kumasi_vectorcapacity_Tm.csv')
file_kum_vec_tn   = Path('Kumasi_vectorcapacity_Tn.csv')
file_kum_vec_tx   = Path('Kumasi_vectorcapacity_Tx.csv')
file_nav_vec_tm   = Path('Navrongo_vectorcapacity_Tm.csv')
file_nav_vec_tn   = Path('Navrongo_vectorcapacity_Tn.csv')
file_nav_vec_tx   = Path('Navrongo_vectorcapacity_Tx.csv')
file_tem_vec_tm   = Path('Tamale_vectorcapacity_Tm.csv')
file_tem_vec_tn   = Path('Tamale_vectorcapacity_Tn.csv')
file_tem_vec_tx   = Path('Tamale_vectorcapacity_Tx.csv')

# %%
#Reading the datasets 

#Dataset for Accra
df_accra_vec_tm = pd.read_csv(file_accra_vec_tm, sep=',')
df_accra_vec_tn = pd.read_csv(file_accra_vec_tn, sep=',')
df_accra_vec_tx = pd.read_csv(file_accra_vec_tx, sep=',')

#Dataset for Kumasi
df_kum_vec_tm   = pd.read_csv(file_kum_vec_tm, sep=',')
df_kum_vec_tn   = pd.read_csv(file_kum_vec_tn, sep=',')
df_kum_vec_tx   = pd.read_csv(file_kum_vec_tx, sep=',')

#Dataset for Navorongo
df_nav_vec_tm   = pd.read_csv(file_nav_vec_tm, sep=',')
df_nav_vec_tn   = pd.read_csv(file_nav_vec_tn, sep=',')
df_nav_vec_tx   = pd.read_csv(file_nav_vec_tx, sep=',')



#Dataset for Tamale
df_tem_vec_tm   = pd.read_csv(file_tem_vec_tm, sep=',')
df_tem_vec_tn   = pd.read_csv(file_tem_vec_tn, sep=',')
df_tem_vec_tx   = pd.read_csv(file_tem_vec_tx, sep=',')

#month = df_tem_vec_tx.month
df_kum_vec_tx.head(4)
month = ['01','02','03','04','05','06','07','08','09','10','11','12']

# %%
#Ploting graphs for Tn,Tm,Tx against P
fig, (ax1, ax2,ax3) = plt.subplots(3,figsize=(10, 15))


labels=['Accra','Navorongo','Tamale','Kumasi']

# A plot of  Tn for each region 
ax1.set_title('Tn')


ax1.plot(month,df_accra_vec_tn.p,marker='o',color="#000")
ax1.plot(month,df_nav_vec_tn.p,marker='o')
ax1.plot(month,df_tem_vec_tn.p,marker='o')
ax1.plot(month,df_kum_vec_tn.p,marker='o')

# A plot of  Tm for each region 
ax2.set_title('Tm')
ax2.plot(month,df_accra_vec_tm.p,marker='o')
ax2.plot(month,df_nav_vec_tm.p,marker='o')
ax2.plot(month,df_tem_vec_tm.p,marker='o')
ax2.plot(month,df_kum_vec_tm.p,marker='o')

# A plot of  Tx for each region 
ax3.set_title('Tx')
ax3.plot(month,df_accra_vec_tx.p,marker='o')
ax3.plot(month,df_nav_vec_tx.p,marker='o')
ax3.plot(month,df_tem_vec_tx.p,marker='o')
ax3.plot(month,df_kum_vec_tx.p,marker='o')

# Setting grid sizes 
ax1.grid(which="minor",alpha=0.3,)
ax1.grid(which="major",alpha=0.6,)
ax1.minorticks_on()

ax2.grid(which="minor",alpha=0.3)
ax2.grid(which="major",alpha=0.6)
ax2.minorticks_on()

ax3.grid(which="minor",alpha=0.3)
ax3.grid(which="major",alpha=0.6)
ax3.minorticks_on()

fig.legend(labels, loc = 'lower right')
plt.legend()
plt.savefig('try.png')

#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
fig, (ax1, ax2,ax3) = plt.subplots(3,figsize=(10, 15))
#fig, (ax1, ax2,ax3) = plt.subplots(3)

labels=['Accra','Navorongo','Tamale','Kumasi']

# A plot of  Tm for each region 
ax1.set_title('Tn')

ax1.plot(month,df_accra_vec_tn.vc,marker='o')
ax1.plot(month,df_nav_vec_tn.vc,marker='o')
ax1.plot(month,df_tem_vec_tn.vc,marker='o')
ax1.plot(month,df_kum_vec_tn.vc,marker='o')

# A plot of  Tn for each region 
ax2.set_title('Tm')
ax2.plot(month,df_accra_vec_tm.vc,marker='o')
ax2.plot(month,df_nav_vec_tm.vc,marker='o')
ax2.plot(month,df_tem_vec_tm.vc,marker='o')
ax2.plot(month,df_kum_vec_tm.vc,marker='o')

# A plot of  Tx for each region 
ax3.set_title('Tx')
ax3.plot(month,df_accra_vec_tx.vc,marker='o')
ax3.plot(month,df_nav_vec_tx.vc,marker='o')
ax3.plot(month,df_tem_vec_tx.vc,marker='o')
ax3.plot(month,df_kum_vec_tx.vc,marker='o')

# Setting grid sizes 
ax1.grid(which="minor",alpha=0.3)
ax1.grid(which="major",alpha=0.6)
ax1.minorticks_on()

ax2.grid(which="minor",alpha=0.3)
ax2.grid(which="major",alpha=0.6)
ax2.minorticks_on()

ax3.grid(which="minor",alpha=0.3)
ax3.grid(which="major",alpha=0.6)
ax3.minorticks_on()

fig.legend(labels, loc = 'lower right')


#fig.legend(labels,bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.1)
plt.legend()
plt.savefig('try11.png')
plt.show()
# Out:
# No handles with labels found to put in legend.
